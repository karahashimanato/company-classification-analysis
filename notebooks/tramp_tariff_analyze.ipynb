# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../")
from src.download_data import download_index_data
from src.volatility import calc_log_returns, calc_rolling_volatility
from src.visualize import plot_rolling_volatility, plot_volatility_heatmap

# %%
df = download_index_data(start_date="2023-01-01", end_date="2025-12-31")
print(df.shape)
df = df.dropna()
print(df.shape)
df.head()
# Out:
# [*********************100%***********************]  9 of 9 completed
# Data downloaded and saved to /home/manaty/financial-contagion-analysis/data/raw/indices_2023-01-01_2025-12-31.csv
# (780, 9)
# (643, 9)
# Ticker            ^AXJO     ^BVSP          ^DJI        ^FTSE        ^GDAXI  \
# Date
# 2023-01-04  7059.200195  105334.0  33269.769531  7585.200195  14490.780273
# 2023-01-05  7063.600098  107518.0  32930.078125  7633.500000  14436.309570
# 2023-01-06  7109.600098  108836.0  33630.609375  7699.500000  14610.019531
# 2023-01-10  7131.000000  110912.0  33704.101562  7694.500000  14774.599609
# 2023-01-11  7195.299805  111763.0  33973.011719  7725.000000  14947.910156
#
# Ticker            ^GSPC          ^HSI         ^IXIC         ^N225
# Date
# 2023-01-04  3852.969971  20793.109375  10458.759766  25716.859375
# 2023-01-05  3808.100098  21052.169922  10305.240234  25820.800781
# 2023-01-06  3895.080078  20991.640625  10569.290039  25973.849609
# 2023-01-10  3919.250000  21331.460938  10742.629883  26175.560547
# 2023-01-11  3969.610107  21436.050781  10931.669922  26446.000000

# %%
returns = calc_log_returns(df)
print(returns.isnull().sum())
print(returns.shape)
returns =returns.dropna()
print(returns.shape)
returns.head()
print(returns.isnull().sum())
# Out:
# Ticker
# ^AXJO     1
# ^BVSP     1
# ^DJI      1
# ^FTSE     1
# ^GDAXI    1
# ^GSPC     1
# ^HSI      1
# ^IXIC     1
# ^N225     1
# dtype: int64
# (643, 9)
# (642, 9)
# Ticker
# ^AXJO     0
# ^BVSP     0
# ^DJI      0
# ^FTSE     0
# ^GDAXI    0
# ^GSPC     0
# ^HSI      0
# ^IXIC     0
# ^N225     0
# dtype: int64

# %%
rolling_vol = calc_rolling_volatility(returns)
print(rolling_vol.isnull().sum())
print(rolling_vol.shape)
rolling_vol = rolling_vol.dropna()
print(rolling_vol.shape)
print(rolling_vol.isnull().sum())
# Out:
# Ticker
# ^AXJO     29
# ^BVSP     29
# ^DJI      29
# ^FTSE     29
# ^GDAXI    29
# ^GSPC     29
# ^HSI      29
# ^IXIC     29
# ^N225     29
# dtype: int64
# (642, 9)
# (613, 9)
# Ticker
# ^AXJO     0
# ^BVSP     0
# ^DJI      0
# ^FTSE     0
# ^GDAXI    0
# ^GSPC     0
# ^HSI      0
# ^IXIC     0
# ^N225     0
# dtype: int64

# %%
plot_rolling_volatility(rolling_vol)

# %%
plot_volatility_heatmap(rolling_vol)
