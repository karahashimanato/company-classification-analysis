# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
sys.path.append("../")
from src.download_data import download_index_data
from src.volatility import calc_log_returns, calc_rolling_volatility 
from src.visualize import plot_rolling_volatility, plot_volatility_heatmap

# %%
df = download_index_data(start_date="2019-01-01", end_date="2021-12-31")
print(df.shape)
df = df.dropna()
print(df.shape)
df.head()
# Out:
# [*********************100%***********************]  9 of 9 completed
# Data downloaded and saved to /home/manaty/financial-contagion-analysis/data/raw/indices_2019-01-01_2021-12-31.csv
# (780, 9)
# (633, 9)
# Ticker            ^AXJO    ^BVSP          ^DJI        ^FTSE        ^GDAXI  \
# Date
# 2019-01-04  5619.399902  91841.0  23433.160156  6837.399902  10767.690430
# 2019-01-07  5683.200195  91699.0  23531.349609  6810.899902  10747.809570
# 2019-01-08  5722.399902  92032.0  23787.449219  6861.600098  10803.980469
# 2019-01-09  5778.299805  93613.0  23879.119141  6906.600098  10893.320312
# 2019-01-10  5795.299805  93806.0  24001.919922  6942.899902  10921.589844
#
# Ticker            ^GSPC          ^HSI        ^IXIC         ^N225
# Date
# 2019-01-04  2531.939941  25626.029297  6738.859863  19561.960938
# 2019-01-07  2549.689941  25835.699219  6823.470215  20038.970703
# 2019-01-08  2574.409912  25875.449219  6897.000000  20204.039062
# 2019-01-09  2584.959961  26462.320312  6957.080078  20427.060547
# 2019-01-10  2596.639893  26521.429688  6986.069824  20163.800781

# %%
returns = calc_log_returns(df)
print(returns.isnull().sum())
print(returns.shape)
returns =returns.dropna()
print(returns.shape)
returns.head()
print(returns.isnull().sum())
# Out:
# Ticker
# ^AXJO     1
# ^BVSP     1
# ^DJI      1
# ^FTSE     1
# ^GDAXI    1
# ^GSPC     1
# ^HSI      1
# ^IXIC     1
# ^N225     1
# dtype: int64
# (633, 9)
# (632, 9)
# Ticker
# ^AXJO     0
# ^BVSP     0
# ^DJI      0
# ^FTSE     0
# ^GDAXI    0
# ^GSPC     0
# ^HSI      0
# ^IXIC     0
# ^N225     0
# dtype: int64

# %%
rolling_vol = calc_rolling_volatility(returns)
print(rolling_vol.isnull().sum())
print(rolling_vol.shape)
rolling_vol = rolling_vol.dropna()
print(rolling_vol.shape)
print(rolling_vol.isnull().sum())
# Out:
# Ticker
# ^AXJO     29
# ^BVSP     29
# ^DJI      29
# ^FTSE     29
# ^GDAXI    29
# ^GSPC     29
# ^HSI      29
# ^IXIC     29
# ^N225     29
# dtype: int64
# (632, 9)
# (603, 9)
# Ticker
# ^AXJO     0
# ^BVSP     0
# ^DJI      0
# ^FTSE     0
# ^GDAXI    0
# ^GSPC     0
# ^HSI      0
# ^IXIC     0
# ^N225     0
# dtype: int64

# %%
plot_rolling_volatility(rolling_vol)

# %%
plot_volatility_heatmap(rolling_vol)
